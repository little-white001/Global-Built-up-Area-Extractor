# %%
! nvidia-smi

# %% [markdown]
# # 1.Mount Google Drive, unzip the code, and configure dependencies

# %%
import os
os.makedirs('/content/codes/',exist_ok=True)
# First, modify the path of global_building_extractor.zip and then unzip it.
# !unzip /content/drive/MyDrive/..../global_building_extractor.zip -d /content/codes/global_building_extractor
# !pip install rasterio

# %% [markdown]
# # 2.run

# %%
# -data_path_s1 --data_path_s2: Path to s1 and s2 images
# --output_dir_merge: If the image exported by GEE is automatically divided into blocks, the result will be saved in this path after splicing
# !python /content/codes/global_building_extractor/run_inference.py \
--data_path_s1 /path_to_s1 \
--data_path_s2 /path_to_s2 \
--resume /content/codes/global_building_extractor/output/exp7/best_weights.pth \
--output_dir /result_folder \
--output_dir_merge /result_folder2 \
--device cuda \
--batch_size 32
